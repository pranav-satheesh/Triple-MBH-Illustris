# %% [markdown]
# This notebook is used for finding the triples from the binary MBHs files. The files should in '../Data'. You'd need
#
# 1. .npz black hole mergers file.
# 2. A hdf5 file which contains the binaries properties of the output from the simulation.
#
# The find_triple_mbhs code is actually found inside Sayeb's directory.

# %%
# Add path to Sayeb's folder
import sys
sys.path.append('/Users/pranavsatheesh/Triples/Github/sayeb')
#sys.path.append('/Users/pranavsatheesh/Triples/Github/Triple-Outcomes/sayeb')

# %%
import find_triple_mbhs as trip

# %%
trip.do_all_inspiral_models('/Users/pranavsatheesh/Triples/Github/Illustris_Data/')
#trip.do_all_inspiral_models('/Users/pranavsatheesh/Triples/Github/Triple-Outcomes/Data/')

#Note that the output file will be stored here in the same directory. Needs to be fixed later.
# Out:
# h = 0.6774, tH = 13802718326.81273 yr.
#
# Reading data from /Users/pranavsatheesh/Triples/Github/Illustris_Data/mbhb-evolution_no-ecc_lc-full-0.6.hdf5
# subhalo SFR:
# 0.0 702.5588989257812 0.8404439966052046
# snapshot:  (9234,) 43 135 9234
# dadt.size:  1828332 (9234, 198)
# masses:  (9234, 2)
# times:  (9234, 198)
# scales:  (9234, 198)
#
# File contains 9234 binaries.
# Nmbhb in nested class:  9234
# /Users/pranavsatheesh/Triples/Github/sayeb/read_mbhb.py:115: RuntimeWarning: invalid value encountered in divide
#   self.tinsp = np.abs(self.sep/self.dadt)
# /Users/pranavsatheesh/Triples/Github/sayeb/read_mbhb.py:116: RuntimeWarning: invalid value encountered in divide
#   self.tinsp_df = np.abs(self.sep/self.dadt_df)
# /Users/pranavsatheesh/Triples/Github/sayeb/read_mbhb.py:117: RuntimeWarning: divide by zero encountered in divide
#   self.tinsp_lc = np.abs(self.sep/self.dadt_lc)
# /Users/pranavsatheesh/Triples/Github/sayeb/read_mbhb.py:117: RuntimeWarning: invalid value encountered in divide
#   self.tinsp_lc = np.abs(self.sep/self.dadt_lc)
# /Users/pranavsatheesh/Triples/Github/sayeb/read_mbhb.py:118: RuntimeWarning: divide by zero encountered in divide
#   self.tinsp_vd = np.abs(self.sep/self.dadt_vd)
# /Users/pranavsatheesh/Triples/Github/sayeb/read_mbhb.py:118: RuntimeWarning: invalid value encountered in divide
#   self.tinsp_vd = np.abs(self.sep/self.dadt_vd)
# /Users/pranavsatheesh/Triples/Github/sayeb/read_mbhb.py:119: RuntimeWarning: invalid value encountered in divide
#   self.tinsp_gw = np.abs(self.sep/self.dadt_gw)
# /Users/pranavsatheesh/Triples/Github/sayeb/read_mbhb.py:135: RuntimeWarning: divide by zero encountered in divide
#   self.evol_z = (1/self.scales)-1
# /Users/pranavsatheesh/Triples/Github/sayeb/find_triple_mbhs.py:434: RuntimeWarning: divide by zero encountered in divide
#   assert np.min(self.ixsep_1st_overtaken / self.ixsep_2nd_overtakes) >= 0, \
# /Users/pranavsatheesh/Triples/Github/sayeb/read_mbhb.py:184: RuntimeWarning: All-NaN slice encountered
#   tinsp_phase_min[i,:] = np.nanmin(np.array([d.tinsp_df[i,:],
# min/max/size sim_tmrg_1st:  -1.0 13583238290.476427 9234
# min/max/size evol_tmrg_1st:  -1.0 3.100072290116735e+16 9234
# min/max/size sim_tmrg_2nd:  -1.0 13739111457.429827 9234
# min/max/size evol_tmrg_2nd:  -1.0 4.300032117703956e+16 9234
#
# calculating inspiral phases...
# Nmbhb= 9234
# ...done.
# min/max time_r_phase:
# 857200298.7665588 13749656336.358547
# 857857396.7275447 4.300001177533844e+16
# 858004617.9419302 4.300032030991866e+16
# 858774123.7039949 4.300032103335078e+16
# making plots...
# 2505
